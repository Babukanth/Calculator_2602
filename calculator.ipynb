# %% [markdown]
# <a href="https://colab.research.google.com/github/Babukanth/Calculator_2602/blob/main/calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator(num1, num2, op):
    if op == "+":
        return num1 + num2

    elif op == "-":
        return num1 - num2

    elif op == "*":
        return num1 * num2

    elif op == "/":
        if num2 == 0:
            return "Error: Division by zero is not allowed."
        return num1 / num2

    else:
        return "Invalid operator"

result = calculator(10, 5, "+")
print("Result =", result)

result = calculator(10, 5, "-")
print("Result =", result)

result = calculator(10, 5, "/")
print("Result =", result)

result = calculator(10, 5, "*")
print("Result =", result)

result = calculator(10, 0, "/")
print("Result =", result)

result = calculator(10, 5, "**")
print("Result =", result)
# Out:
# Result = 15
# Result = 5
# Result = 2.0
# Result = 50
# Result = Error: Division by zero is not allowed.
# Result = Invalid operator

# %%
def calculator(num1, num2, op):
    # Perform the calculation
    if op == "+":
        result = num1 + num2

    elif op == "-":
        result = num1 - num2

    elif op == "*":
        result = num1 * num2

    elif op == "/":
        if num2 == 0:
            return "Error: Division by zero is not allowed."
        result = num1 / num2

    else:
        return "Invalid operator"

    # Determine if result is positive, negative, or zero
    if result > 0:
        sign = "Positive"
    elif result < 0:
        sign = "Negative"
    else:
        sign = "Zero"

    return f"Result = {result}\n{sign}"

result = calculator(10, 5, "+")
print("Result =", result)

result = calculator(10, 5, "-")
print("Result =", result)

result = calculator(10, -5, "/")
print("Result =", result)

result = calculator(10, 5, "*")
print("Result =", result)

result = calculator(10, 0, "/")
print("Result =", result)

result = calculator(10, 5, "**")
print("Result =", result)
# Out:
# Result = Result = 15
# Positive
# Result = Result = 5
# Positive
# Result = Result = -2.0
# Negative
# Result = Result = 50
# Positive
# Result = Error: Division by zero is not allowed.
# Result = Invalid operator

# %%
def grade_calculator(name, m1, m2, m3):
    # Calculate total and percentage
    total = m1 + m2 + m3
    percentage = (total / 300) * 100

    # Determine grade
    if percentage >= 75:
        grade = "A"
    elif percentage >= 60:
        grade = "B"
    elif percentage >= 40:
        grade = "C"
    else:
        grade = "F"

    # Prepare output
    print(name)
    print(f"Total: {total}/300")
    print(f"Percentage: {percentage}%")
    print(f"Grade: {grade}")

grade_calculator("Raj", 80, 70, 90)
grade_calculator("Babu", 85, 90, 95)
grade_calculator("Aananthi", 99, 99, 99)
# Out:
# Raj
# Total: 240/300
# Percentage: 80.0%
# Grade: A
# Babu
# Total: 270/300
# Percentage: 90.0%
# Grade: A
# Aananthi
# Total: 297/300
# Percentage: 99.0%
# Grade: A
